# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import numpy as np
import gc
# Out:
# /Users/ruiqianyang/anaconda3/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_9.4.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
####data from r
train_r=pd.read_csv('train_r.csv')
test_r=pd.read_csv('test_r.csv')

#del X,test_x
X=train_r.drop(train_r.columns[0],axis=1)
test_x=test_r.drop(test_r.columns[0],axis=1)

label = pd.read_pickle('train_Basic.pkl')
y = label['isFraud']

train=pd.read_pickle('train_Basic.pkl')
test=pd.read_pickle('test_Basic.pkl')
y=y.reset_index(drop=False)
train=train.reset_index(drop=False)
test=test.reset_index(drop=False)

X['TransactionID']=train['TransactionID']
test_x['TransactionID']=test['TransactionID']

X['month']=train['month']
test_x['month']=test['month']

import datetime
startDT = datetime.datetime.strptime('2017-12-01', '%Y-%m-%d')
train['TransactionDT1']=train['TransactionDT'].apply(lambda x:(startDT+datetime.timedelta(seconds=x)))
X['DT_M'] = ((train['TransactionDT1'].dt.year-2017)*12 + train['TransactionDT1'].dt.month).astype(np.int8)
X['DT_M']


for df in [X, test_x]:
    for col_1 in df.columns:
        if df[col_1].dtype == 'object':
            print(col_1)
            le = LabelEncoder()
            le.fit(list(train_r[col_1].astype(str).values) + 
                   list(test_r[col_1].astype(str).values))
            df[col_1] = le.transform(list(df[col_1].astype(str).values))
    df.fillna(-999,inplace=True)
    df[np.isinf(df.values)==True] = 999

# %%
###minify data
X_12=X[X['month']==12]
y_12=label[label['month']==12]['isFraud']

# %%
##############################XGBOOST kfold##################################
import xgboost as xgb
from sklearn.model_selection import KFold,GroupKFold
import time
start=time.time()
       
def make_predictions(tr_df, tt_df, features_columns, target, 
                      NFOLDS=10):
    
    #folds = GroupKFold(n_splits=NFOLDS)  #GroupKFold by XX
    folds = KFold(n_splits=NFOLDS, shuffle=False, random_state=42)

    X,y = tr_df[features_columns], tr_df[target]    
    P,P_y = tt_df[features_columns], tt_df[target]  
    #split_groups = tr_df['DT_M']      #GroupKFold by XX

    tt_df = tt_df[['TransactionID',target]] 
    #tt_df = tt_df[target]   
    predictions = np.zeros(len(tt_df))
    
    for fold_, (trn_idx, val_idx) in enumerate(folds.split(X, y)):
   # for fold_, (trn_idx, val_idx) in enumerate(folds.split(X, y, groups=split_groups)): #GroupKFold by XX
        print('Fold:',fold_)
        tr_x, tr_y = X.iloc[trn_idx,:], y[trn_idx]
        vl_x, vl_y = X.iloc[val_idx,:], y[val_idx]
            
        print(len(tr_x),len(vl_x))
#         tr_data = xgb.DMatrix(tr_x, label=tr_y)
#         vl_data = xgb.DMatrix(vl_x, label=vl_y)
#         P_D = xgb.DMatrix(P)
        
 #       print('train month is '+str(tr_x['month'].unique()))
 #       print('test month is '+str(vl_x['month'].unique()))
#        tr_data = lgb.Dataset(tr_x, label=tr_y)

#         if LOCAL_TEST:
#             vl_data = lgb.Dataset(P, label=P_y) 
#         else:
#             vl_data = lgb.Dataset(vl_x, label=vl_y)  

#         estimator = xgb.XGBClassifier.train(
#             xgb_params,
#             tr_data,
#             evals = [(tr_data, 'train'),(vl_data, 'valid')], 
#             verbose_eval = 50
#         ) 

        clf = xgb.XGBClassifier(
             n_jobs=4,
            n_estimators=2000,
            max_depth=20,
            learning_rate=0.035,
            subsample=0.7,
            colsample_bytree=0.7463058454739352,
            #tree_method='gpu_hist',  # THE MAGICAL PARAMETER,
            random_state=2019,
            reg_alpha=0.39871702770778467,
            reg_lamdba=0.24309304355829786
#                gamma=0.6665437467229817,
#                min_child_weight=,
#                max_delta_step=,
#           min_child_samples= 170
        )
    
        clf.fit(tr_x, tr_y,eval_set = [(tr_x, tr_y),(vl_x, vl_y)], eval_metric="auc",
                early_stopping_rounds = 50)
        print(time.time()-start)
        print('ROC accuracy: {}'.format(roc_auc_score(vl_y, clf.predict_proba(vl_x)[:, 1])))
        #pp_p+= clf.predict_proba(P)[:,1] 
     
        pp_p = clf.predict_proba(P)[:,1]
        
        print(pp_p)
        tt_df['fold '+str(fold_)]=pp_p
        predictions += pp_p/NFOLDS     #consider weighting predictions??
       # print('weight is '+str(w[fold_]))
       # predictions += pp_p*w[fold_]
        
        if LOCAL_TEST:
            feature_imp = pd.DataFrame(sorted(zip(estimator.feature_importance(),X.columns)), 
                                       columns=['Value','Feature'])
            print(feature_imp)
        
        del tr_x, tr_y, vl_x, vl_y
        gc.collect()
    
    tt_df['prediction'] = predictions
    
    return tt_df   

########################### Model Train
LOCAL_TEST = False
TARGET = 'isFraud'

#assign train_df and test_df:
train_df=X.iloc[:]
train_df['isFraud']=y['isFraud']
test_df=test_x.iloc[:]
test_df['isFraud']=0

#!!!if transactionID is index: 
train_df=train_df.reset_index(drop=False)
test_df=test_df.reset_index(drop=False)
    
#make sure 'DT_M' and'TransactionID' are not in feature list
features_columns=list(set(X)-{'DT_M','TransactionID'})     
print(len(features_columns))
print(len(X.columns))

test_predictions = make_predictions(train_df, test_df, features_columns, TARGET,NFOLDS=10)
####End XGB KFOLD
# Out:
# 227
# 229
# Fold: 0
# 472432 118108
# [0]	validation_0-auc:0.879091	validation_1-auc:0.847155
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.894005	validation_1-auc:0.845267
# [2]	validation_0-auc:0.902255	validation_1-auc:0.850384
# [3]	validation_0-auc:0.905102	validation_1-auc:0.852482
# [4]	validation_0-auc:0.908332	validation_1-auc:0.856521
# [5]	validation_0-auc:0.910613	validation_1-auc:0.859506
# [6]	validation_0-auc:0.915004	validation_1-auc:0.862178
# [7]	validation_0-auc:0.915699	validation_1-auc:0.862331
# [8]	validation_0-auc:0.916194	validation_1-auc:0.862227
# [9]	validation_0-auc:0.917422	validation_1-auc:0.861611
# [10]	validation_0-auc:0.919223	validation_1-auc:0.862658
# [11]	validation_0-auc:0.921672	validation_1-auc:0.864194
# [12]	validation_0-auc:0.92311	validation_1-auc:0.865486
# [13]	validation_0-auc:0.924997	validation_1-auc:0.86625
# [14]	validation_0-auc:0.927505	validation_1-auc:0.867909
# [15]	validation_0-auc:0.929572	validation_1-auc:0.868518
# [16]	validation_0-auc:0.931394	validation_1-auc:0.871011
# [17]	validation_0-auc:0.933807	validation_1-auc:0.871032
# [18]	validation_0-auc:0.934535	validation_1-auc:0.871286
# [19]	validation_0-auc:0.936498	validation_1-auc:0.872304
# [20]	validation_0-auc:0.939276	validation_1-auc:0.873839
# [21]	validation_0-auc:0.940091	validation_1-auc:0.874488
# [22]	validation_0-auc:0.940519	validation_1-auc:0.874715
# [23]	validation_0-auc:0.941419	validation_1-auc:0.874529
# [24]	validation_0-auc:0.94361	validation_1-auc:0.876447
# [25]	validation_0-auc:0.944501	validation_1-auc:0.877167
# [26]	validation_0-auc:0.945159	validation_1-auc:0.877971
# [27]	validation_0-auc:0.946127	validation_1-auc:0.879082
# [28]	validation_0-auc:0.94692	validation_1-auc:0.87949
# [29]	validation_0-auc:0.94766	validation_1-auc:0.880521
# [30]	validation_0-auc:0.948338	validation_1-auc:0.880777
# [31]	validation_0-auc:0.948884	validation_1-auc:0.881159
# [32]	validation_0-auc:0.950313	validation_1-auc:0.882611
# [33]	validation_0-auc:0.951161	validation_1-auc:0.8832
# [34]	validation_0-auc:0.951823	validation_1-auc:0.883433
# [35]	validation_0-auc:0.952971	validation_1-auc:0.884051
# [36]	validation_0-auc:0.953831	validation_1-auc:0.884018
# [37]	validation_0-auc:0.954895	validation_1-auc:0.884387
# [38]	validation_0-auc:0.955496	validation_1-auc:0.884594
# [39]	validation_0-auc:0.95648	validation_1-auc:0.884892
# [40]	validation_0-auc:0.958079	validation_1-auc:0.885309
# [41]	validation_0-auc:0.959202	validation_1-auc:0.886079
# [42]	validation_0-auc:0.96005	validation_1-auc:0.886174
# [43]	validation_0-auc:0.960605	validation_1-auc:0.886306
# [44]	validation_0-auc:0.961433	validation_1-auc:0.886756
# [45]	validation_0-auc:0.961893	validation_1-auc:0.886613
# [46]	validation_0-auc:0.962791	validation_1-auc:0.886935
# [47]	validation_0-auc:0.96341	validation_1-auc:0.8872
# [48]	validation_0-auc:0.96398	validation_1-auc:0.887413
# [49]	validation_0-auc:0.964869	validation_1-auc:0.887963
# [50]	validation_0-auc:0.965498	validation_1-auc:0.88785
# [51]	validation_0-auc:0.966206	validation_1-auc:0.887967
# [52]	validation_0-auc:0.967093	validation_1-auc:0.888539
# [53]	validation_0-auc:0.968293	validation_1-auc:0.888923
# [54]	validation_0-auc:0.968706	validation_1-auc:0.889224
# [55]	validation_0-auc:0.969149	validation_1-auc:0.889586
# [56]	validation_0-auc:0.969564	validation_1-auc:0.889976
# [57]	validation_0-auc:0.970265	validation_1-auc:0.890077
# [58]	validation_0-auc:0.970748	validation_1-auc:0.890087
# [59]	validation_0-auc:0.971471	validation_1-auc:0.890543
# [60]	validation_0-auc:0.971885	validation_1-auc:0.89048
# [61]	validation_0-auc:0.972349	validation_1-auc:0.891008
# [62]	validation_0-auc:0.973079	validation_1-auc:0.891084
# [63]	validation_0-auc:0.973642	validation_1-auc:0.891281
# [64]	validation_0-auc:0.974076	validation_1-auc:0.891579
# [65]	validation_0-auc:0.97488	validation_1-auc:0.891877
# [66]	validation_0-auc:0.975472	validation_1-auc:0.892556
# [67]	validation_0-auc:0.975946	validation_1-auc:0.892706
# [68]	validation_0-auc:0.976475	validation_1-auc:0.892634
# [69]	validation_0-auc:0.976919	validation_1-auc:0.89253
# [70]	validation_0-auc:0.977686	validation_1-auc:0.893281
# [71]	validation_0-auc:0.97873	validation_1-auc:0.893533
# [72]	validation_0-auc:0.979578	validation_1-auc:0.893882
# [73]	validation_0-auc:0.980392	validation_1-auc:0.894142
# [74]	validation_0-auc:0.98081	validation_1-auc:0.89425
# [75]	validation_0-auc:0.981722	validation_1-auc:0.894789
# [76]	validation_0-auc:0.982169	validation_1-auc:0.895258
# [77]	validation_0-auc:0.982703	validation_1-auc:0.895184
# [78]	validation_0-auc:0.983537	validation_1-auc:0.895852
# [79]	validation_0-auc:0.984042	validation_1-auc:0.896017
# [80]	validation_0-auc:0.984609	validation_1-auc:0.896494
# [81]	validation_0-auc:0.985083	validation_1-auc:0.896618
# [82]	validation_0-auc:0.985588	validation_1-auc:0.896944
# [83]	validation_0-auc:0.986188	validation_1-auc:0.897493
# [84]	validation_0-auc:0.986799	validation_1-auc:0.897335
# [85]	validation_0-auc:0.98718	validation_1-auc:0.898063
# [86]	validation_0-auc:0.987761	validation_1-auc:0.898311
# [87]	validation_0-auc:0.988334	validation_1-auc:0.898841
# [88]	validation_0-auc:0.988726	validation_1-auc:0.89906
# [89]	validation_0-auc:0.989124	validation_1-auc:0.898998
# [90]	validation_0-auc:0.989478	validation_1-auc:0.899658
# [91]	validation_0-auc:0.99012	validation_1-auc:0.899878
# [92]	validation_0-auc:0.990622	validation_1-auc:0.899945
# [93]	validation_0-auc:0.990958	validation_1-auc:0.900165
# [94]	validation_0-auc:0.991394	validation_1-auc:0.90065
# [95]	validation_0-auc:0.991702	validation_1-auc:0.900874
# [96]	validation_0-auc:0.992031	validation_1-auc:0.900996
# [97]	validation_0-auc:0.992416	validation_1-auc:0.90169
# [98]	validation_0-auc:0.992679	validation_1-auc:0.901904
# [99]	validation_0-auc:0.99299	validation_1-auc:0.902527
# [100]	validation_0-auc:0.993219	validation_1-auc:0.902533
# [101]	validation_0-auc:0.993607	validation_1-auc:0.902595
# [102]	validation_0-auc:0.993931	validation_1-auc:0.903105
# [103]	validation_0-auc:0.994247	validation_1-auc:0.903308
# [104]	validation_0-auc:0.994447	validation_1-auc:0.903029
# [105]	validation_0-auc:0.994708	validation_1-auc:0.90343
# [106]	validation_0-auc:0.994946	validation_1-auc:0.903558
# [107]	validation_0-auc:0.995183	validation_1-auc:0.903799
# [108]	validation_0-auc:0.995403	validation_1-auc:0.903897
# [109]	validation_0-auc:0.995652	validation_1-auc:0.904242
# [110]	validation_0-auc:0.995841	validation_1-auc:0.904536
# [111]	validation_0-auc:0.996013	validation_1-auc:0.904403
# [112]	validation_0-auc:0.99622	validation_1-auc:0.904673
# [113]	validation_0-auc:0.99639	validation_1-auc:0.90455
# [114]	validation_0-auc:0.996554	validation_1-auc:0.904759
# [115]	validation_0-auc:0.996689	validation_1-auc:0.904988
# [116]	validation_0-auc:0.996818	validation_1-auc:0.905179
# [117]	validation_0-auc:0.996939	validation_1-auc:0.905541
# [118]	validation_0-auc:0.99709	validation_1-auc:0.905534
# [119]	validation_0-auc:0.997203	validation_1-auc:0.90571
# [120]	validation_0-auc:0.997361	validation_1-auc:0.905869
# [121]	validation_0-auc:0.997506	validation_1-auc:0.906122
# [122]	validation_0-auc:0.997619	validation_1-auc:0.906408
# [123]	validation_0-auc:0.997743	validation_1-auc:0.906571
# [124]	validation_0-auc:0.997837	validation_1-auc:0.906806
# [125]	validation_0-auc:0.997941	validation_1-auc:0.907121
# [126]	validation_0-auc:0.998032	validation_1-auc:0.907159
# [127]	validation_0-auc:0.998113	validation_1-auc:0.907015
# [128]	validation_0-auc:0.998212	validation_1-auc:0.90734
# [129]	validation_0-auc:0.998288	validation_1-auc:0.907457
# [130]	validation_0-auc:0.998383	validation_1-auc:0.907589
# [131]	validation_0-auc:0.998456	validation_1-auc:0.907538
# [132]	validation_0-auc:0.998524	validation_1-auc:0.907594
# [133]	validation_0-auc:0.99857	validation_1-auc:0.907736
# [134]	validation_0-auc:0.998655	validation_1-auc:0.907811
# [135]	validation_0-auc:0.998719	validation_1-auc:0.908103
# [136]	validation_0-auc:0.998764	validation_1-auc:0.908215
# [137]	validation_0-auc:0.998827	validation_1-auc:0.908431
# [138]	validation_0-auc:0.998879	validation_1-auc:0.908478
# [139]	validation_0-auc:0.998941	validation_1-auc:0.90836
# [140]	validation_0-auc:0.998984	validation_1-auc:0.908671
# [141]	validation_0-auc:0.999026	validation_1-auc:0.908743
# [142]	validation_0-auc:0.999078	validation_1-auc:0.908745
# [143]	validation_0-auc:0.999124	validation_1-auc:0.90884
# [144]	validation_0-auc:0.999162	validation_1-auc:0.90901
# [145]	validation_0-auc:0.999201	validation_1-auc:0.909031
# [146]	validation_0-auc:0.999237	validation_1-auc:0.909244
# [147]	validation_0-auc:0.999262	validation_1-auc:0.909173
# [148]	validation_0-auc:0.999304	validation_1-auc:0.909206
# [149]	validation_0-auc:0.99934	validation_1-auc:0.909433
# [150]	validation_0-auc:0.999367	validation_1-auc:0.909478
# [151]	validation_0-auc:0.999394	validation_1-auc:0.909631
# [152]	validation_0-auc:0.999422	validation_1-auc:0.90972
# [153]	validation_0-auc:0.999448	validation_1-auc:0.909906
# [154]	validation_0-auc:0.999476	validation_1-auc:0.909936
# [155]	validation_0-auc:0.999497	validation_1-auc:0.910077
# [156]	validation_0-auc:0.99952	validation_1-auc:0.910137
# [157]	validation_0-auc:0.99954	validation_1-auc:0.910159
# [158]	validation_0-auc:0.999559	validation_1-auc:0.910046
# [159]	validation_0-auc:0.999577	validation_1-auc:0.910217
# [160]	validation_0-auc:0.999599	validation_1-auc:0.910205
# [161]	validation_0-auc:0.999617	validation_1-auc:0.910136
# [162]	validation_0-auc:0.999635	validation_1-auc:0.910369
# [163]	validation_0-auc:0.999652	validation_1-auc:0.910666
# [164]	validation_0-auc:0.999666	validation_1-auc:0.910928
# [165]	validation_0-auc:0.999678	validation_1-auc:0.911225
# [166]	validation_0-auc:0.999692	validation_1-auc:0.911324
# [167]	validation_0-auc:0.999704	validation_1-auc:0.911345
# [168]	validation_0-auc:0.999715	validation_1-auc:0.911358
# [169]	validation_0-auc:0.999728	validation_1-auc:0.91141
# [170]	validation_0-auc:0.999739	validation_1-auc:0.911366
# [171]	validation_0-auc:0.999748	validation_1-auc:0.911524
# [172]	validation_0-auc:0.999757	validation_1-auc:0.911518
# [173]	validation_0-auc:0.999769	validation_1-auc:0.911617
# [174]	validation_0-auc:0.999777	validation_1-auc:0.911536
# [175]	validation_0-auc:0.999786	validation_1-auc:0.911664
# [176]	validation_0-auc:0.999796	validation_1-auc:0.911867
# [177]	validation_0-auc:0.999804	validation_1-auc:0.911903
# [178]	validation_0-auc:0.99981	validation_1-auc:0.911935
# [179]	validation_0-auc:0.999816	validation_1-auc:0.912031
# [180]	validation_0-auc:0.999822	validation_1-auc:0.91234
# [181]	validation_0-auc:0.999829	validation_1-auc:0.912483
# [182]	validation_0-auc:0.999835	validation_1-auc:0.912515
# [183]	validation_0-auc:0.999842	validation_1-auc:0.912537
# [184]	validation_0-auc:0.999846	validation_1-auc:0.912634
# [185]	validation_0-auc:0.99985	validation_1-auc:0.912603
# [186]	validation_0-auc:0.999856	validation_1-auc:0.912807
# [187]	validation_0-auc:0.999861	validation_1-auc:0.913006
# [188]	validation_0-auc:0.999865	validation_1-auc:0.912932
# [189]	validation_0-auc:0.999868	validation_1-auc:0.913114
# [190]	validation_0-auc:0.999875	validation_1-auc:0.912994
# [191]	validation_0-auc:0.999878	validation_1-auc:0.913056
# [192]	validation_0-auc:0.999882	validation_1-auc:0.913106
# [193]	validation_0-auc:0.999884	validation_1-auc:0.913143
# [194]	validation_0-auc:0.999888	validation_1-auc:0.913121
# [195]	validation_0-auc:0.999893	validation_1-auc:0.913187
# [196]	validation_0-auc:0.999896	validation_1-auc:0.913197
# [197]	validation_0-auc:0.999902	validation_1-auc:0.913177
# [198]	validation_0-auc:0.999904	validation_1-auc:0.913153
# [199]	validation_0-auc:0.999907	validation_1-auc:0.913252
# [200]	validation_0-auc:0.99991	validation_1-auc:0.913292
# [201]	validation_0-auc:0.999911	validation_1-auc:0.913257
# [202]	validation_0-auc:0.999916	validation_1-auc:0.91332
# [203]	validation_0-auc:0.999919	validation_1-auc:0.913254
# [204]	validation_0-auc:0.999923	validation_1-auc:0.91315
# [205]	validation_0-auc:0.999924	validation_1-auc:0.913237
# [206]	validation_0-auc:0.999927	validation_1-auc:0.913416
# [207]	validation_0-auc:0.999929	validation_1-auc:0.91345
# [208]	validation_0-auc:0.999932	validation_1-auc:0.913394
# [209]	validation_0-auc:0.999934	validation_1-auc:0.913501
# [210]	validation_0-auc:0.999937	validation_1-auc:0.913674
# [211]	validation_0-auc:0.999939	validation_1-auc:0.913689
# [212]	validation_0-auc:0.999942	validation_1-auc:0.913734
# [213]	validation_0-auc:0.999945	validation_1-auc:0.913743
# [214]	validation_0-auc:0.999948	validation_1-auc:0.913714
# [215]	validation_0-auc:0.99995	validation_1-auc:0.913771
# [216]	validation_0-auc:0.999951	validation_1-auc:0.913854
# [217]	validation_0-auc:0.999952	validation_1-auc:0.913869
# [218]	validation_0-auc:0.999954	validation_1-auc:0.913975
# [219]	validation_0-auc:0.999955	validation_1-auc:0.913897
# [220]	validation_0-auc:0.999956	validation_1-auc:0.913995
# [221]	validation_0-auc:0.999958	validation_1-auc:0.913944
# [222]	validation_0-auc:0.999959	validation_1-auc:0.914033
# [223]	validation_0-auc:0.999961	validation_1-auc:0.914156
# [224]	validation_0-auc:0.999963	validation_1-auc:0.914107
# [225]	validation_0-auc:0.999964	validation_1-auc:0.914027
# [226]	validation_0-auc:0.999965	validation_1-auc:0.914114
# [227]	validation_0-auc:0.999966	validation_1-auc:0.914178
# [228]	validation_0-auc:0.999967	validation_1-auc:0.914123
# [229]	validation_0-auc:0.999968	validation_1-auc:0.914093
# [230]	validation_0-auc:0.999968	validation_1-auc:0.913896
# [231]	validation_0-auc:0.999969	validation_1-auc:0.913974
# [232]	validation_0-auc:0.99997	validation_1-auc:0.91391
# [233]	validation_0-auc:0.999973	validation_1-auc:0.913864
# [234]	validation_0-auc:0.999973	validation_1-auc:0.914021
# [235]	validation_0-auc:0.999974	validation_1-auc:0.913991
# [236]	validation_0-auc:0.999975	validation_1-auc:0.913898
# [237]	validation_0-auc:0.999976	validation_1-auc:0.913862
# Stopping. Best iteration:
# [227]	validation_0-auc:0.999966	validation_1-auc:0.914178
#
# 7125.403833150864
# ROC accuracy: 0.9141784974972538
# [0.00094068 0.00175523 0.00167553 ... 0.00583385 0.00639056 0.00446378]
# /Users/ruiqianyang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fold: 1
# 472432 118108
# [0]	validation_0-auc:0.878523	validation_1-auc:0.842593
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.890128	validation_1-auc:0.855975
# [2]	validation_0-auc:0.898155	validation_1-auc:0.859606
# [3]	validation_0-auc:0.899785	validation_1-auc:0.861512
# [4]	validation_0-auc:0.903683	validation_1-auc:0.863945
# [5]	validation_0-auc:0.905713	validation_1-auc:0.86682
# [6]	validation_0-auc:0.908343	validation_1-auc:0.868858
# [7]	validation_0-auc:0.909361	validation_1-auc:0.869586
# [8]	validation_0-auc:0.910728	validation_1-auc:0.87023
# [9]	validation_0-auc:0.913588	validation_1-auc:0.871322
# [10]	validation_0-auc:0.914529	validation_1-auc:0.871851
# [11]	validation_0-auc:0.916091	validation_1-auc:0.872762
# [12]	validation_0-auc:0.917564	validation_1-auc:0.873574
# [13]	validation_0-auc:0.919815	validation_1-auc:0.875593
# [14]	validation_0-auc:0.921758	validation_1-auc:0.876325
# [15]	validation_0-auc:0.92397	validation_1-auc:0.878806
# [16]	validation_0-auc:0.926223	validation_1-auc:0.880059
# [17]	validation_0-auc:0.927601	validation_1-auc:0.881378
# [18]	validation_0-auc:0.928779	validation_1-auc:0.881357
# [19]	validation_0-auc:0.931102	validation_1-auc:0.882205
# [20]	validation_0-auc:0.931903	validation_1-auc:0.882932
# [21]	validation_0-auc:0.932957	validation_1-auc:0.883519
# [22]	validation_0-auc:0.934431	validation_1-auc:0.883826
# [23]	validation_0-auc:0.935475	validation_1-auc:0.884552
# [24]	validation_0-auc:0.936524	validation_1-auc:0.885143
# [25]	validation_0-auc:0.9371	validation_1-auc:0.885206
# [26]	validation_0-auc:0.938286	validation_1-auc:0.886224
# [27]	validation_0-auc:0.938946	validation_1-auc:0.886322
# [28]	validation_0-auc:0.939774	validation_1-auc:0.887303
# [29]	validation_0-auc:0.940912	validation_1-auc:0.887502
# [30]	validation_0-auc:0.942085	validation_1-auc:0.888853
# [31]	validation_0-auc:0.943245	validation_1-auc:0.88917
# [32]	validation_0-auc:0.944432	validation_1-auc:0.890189
# [33]	validation_0-auc:0.9456	validation_1-auc:0.890817
# [34]	validation_0-auc:0.946214	validation_1-auc:0.89119
# [35]	validation_0-auc:0.947273	validation_1-auc:0.891533
# [36]	validation_0-auc:0.948531	validation_1-auc:0.892302
# [37]	validation_0-auc:0.949228	validation_1-auc:0.89294
# [38]	validation_0-auc:0.950133	validation_1-auc:0.893225
# [39]	validation_0-auc:0.951069	validation_1-auc:0.893433
# [40]	validation_0-auc:0.951892	validation_1-auc:0.894251
# [41]	validation_0-auc:0.953094	validation_1-auc:0.895121
# [42]	validation_0-auc:0.953858	validation_1-auc:0.895849
# [43]	validation_0-auc:0.954708	validation_1-auc:0.896289
# [44]	validation_0-auc:0.955281	validation_1-auc:0.897211
# [45]	validation_0-auc:0.956034	validation_1-auc:0.897626
# [46]	validation_0-auc:0.957209	validation_1-auc:0.898165
# [47]	validation_0-auc:0.957949	validation_1-auc:0.898841
# [48]	validation_0-auc:0.958335	validation_1-auc:0.899308
# [49]	validation_0-auc:0.959403	validation_1-auc:0.900008
# [50]	validation_0-auc:0.960333	validation_1-auc:0.900487
# [51]	validation_0-auc:0.961788	validation_1-auc:0.901245
# [52]	validation_0-auc:0.962543	validation_1-auc:0.90179
# [53]	validation_0-auc:0.963179	validation_1-auc:0.902146
# [54]	validation_0-auc:0.964032	validation_1-auc:0.902606
# [55]	validation_0-auc:0.965132	validation_1-auc:0.902777
# [56]	validation_0-auc:0.965698	validation_1-auc:0.903002
# [57]	validation_0-auc:0.966514	validation_1-auc:0.903644
# [58]	validation_0-auc:0.967377	validation_1-auc:0.904186
# [59]	validation_0-auc:0.968273	validation_1-auc:0.904724
# [60]	validation_0-auc:0.969114	validation_1-auc:0.905353
# [61]	validation_0-auc:0.970122	validation_1-auc:0.906092
# [62]	validation_0-auc:0.970999	validation_1-auc:0.906605
# [63]	validation_0-auc:0.971646	validation_1-auc:0.906809
# [64]	validation_0-auc:0.972615	validation_1-auc:0.907115
# [65]	validation_0-auc:0.973618	validation_1-auc:0.908088
# [66]	validation_0-auc:0.974411	validation_1-auc:0.908793
# [67]	validation_0-auc:0.974756	validation_1-auc:0.909063
# [68]	validation_0-auc:0.975295	validation_1-auc:0.909083
# [69]	validation_0-auc:0.976441	validation_1-auc:0.909726
# [70]	validation_0-auc:0.976984	validation_1-auc:0.910372
# [71]	validation_0-auc:0.977726	validation_1-auc:0.910716
# [72]	validation_0-auc:0.978747	validation_1-auc:0.911208
# [73]	validation_0-auc:0.979725	validation_1-auc:0.911558
# [74]	validation_0-auc:0.980225	validation_1-auc:0.912123
# [75]	validation_0-auc:0.980626	validation_1-auc:0.912685
# [76]	validation_0-auc:0.981167	validation_1-auc:0.913173
# [77]	validation_0-auc:0.981925	validation_1-auc:0.913773
# [78]	validation_0-auc:0.982654	validation_1-auc:0.914132
# [79]	validation_0-auc:0.98325	validation_1-auc:0.914103
# [80]	validation_0-auc:0.983481	validation_1-auc:0.914881
# [81]	validation_0-auc:0.983838	validation_1-auc:0.915289
# [82]	validation_0-auc:0.98425	validation_1-auc:0.915923
# [83]	validation_0-auc:0.984657	validation_1-auc:0.916034
# [84]	validation_0-auc:0.985293	validation_1-auc:0.916158
# [85]	validation_0-auc:0.98548	validation_1-auc:0.916795
# [86]	validation_0-auc:0.986001	validation_1-auc:0.917318
# [87]	validation_0-auc:0.986525	validation_1-auc:0.917735
# [88]	validation_0-auc:0.986815	validation_1-auc:0.918102
# [89]	validation_0-auc:0.987308	validation_1-auc:0.918995
# [90]	validation_0-auc:0.987829	validation_1-auc:0.919729
# [91]	validation_0-auc:0.98827	validation_1-auc:0.920015
# [92]	validation_0-auc:0.988819	validation_1-auc:0.920248
# [93]	validation_0-auc:0.989254	validation_1-auc:0.920366
# [94]	validation_0-auc:0.989695	validation_1-auc:0.920908
# [95]	validation_0-auc:0.990021	validation_1-auc:0.921585
# [96]	validation_0-auc:0.990409	validation_1-auc:0.922038
# [97]	validation_0-auc:0.990829	validation_1-auc:0.922323
# [98]	validation_0-auc:0.991103	validation_1-auc:0.922226
# [99]	validation_0-auc:0.991335	validation_1-auc:0.922413
# [100]	validation_0-auc:0.991686	validation_1-auc:0.922582
# [101]	validation_0-auc:0.991992	validation_1-auc:0.922708
# [102]	validation_0-auc:0.992337	validation_1-auc:0.922698
# [103]	validation_0-auc:0.992618	validation_1-auc:0.922702
# [104]	validation_0-auc:0.992875	validation_1-auc:0.922981
# [105]	validation_0-auc:0.99312	validation_1-auc:0.923226
# [106]	validation_0-auc:0.993352	validation_1-auc:0.92324
# [107]	validation_0-auc:0.993571	validation_1-auc:0.923589
# [108]	validation_0-auc:0.993845	validation_1-auc:0.924105
# [109]	validation_0-auc:0.994063	validation_1-auc:0.924382
# [110]	validation_0-auc:0.994276	validation_1-auc:0.924564
# [111]	validation_0-auc:0.994533	validation_1-auc:0.924715
# [112]	validation_0-auc:0.994749	validation_1-auc:0.924837
# [113]	validation_0-auc:0.994963	validation_1-auc:0.924972
# [114]	validation_0-auc:0.995163	validation_1-auc:0.925143
# [115]	validation_0-auc:0.995385	validation_1-auc:0.925385
# [116]	validation_0-auc:0.995534	validation_1-auc:0.925502
# [117]	validation_0-auc:0.995696	validation_1-auc:0.925612
# [118]	validation_0-auc:0.995907	validation_1-auc:0.925823
# [119]	validation_0-auc:0.996027	validation_1-auc:0.925864
# [120]	validation_0-auc:0.996245	validation_1-auc:0.9262
# [121]	validation_0-auc:0.996356	validation_1-auc:0.926532
# [122]	validation_0-auc:0.996465	validation_1-auc:0.926442
# [123]	validation_0-auc:0.99659	validation_1-auc:0.926708
# [124]	validation_0-auc:0.996762	validation_1-auc:0.926922
# [125]	validation_0-auc:0.9969	validation_1-auc:0.927112
# [126]	validation_0-auc:0.997042	validation_1-auc:0.927116
# [127]	validation_0-auc:0.997134	validation_1-auc:0.927342
# [128]	validation_0-auc:0.997272	validation_1-auc:0.927627
# [129]	validation_0-auc:0.997398	validation_1-auc:0.927921
# [130]	validation_0-auc:0.997547	validation_1-auc:0.928347
# [131]	validation_0-auc:0.997678	validation_1-auc:0.928411
# [132]	validation_0-auc:0.99779	validation_1-auc:0.928397
# [133]	validation_0-auc:0.997881	validation_1-auc:0.928322
# [134]	validation_0-auc:0.997988	validation_1-auc:0.928348
# [135]	validation_0-auc:0.998068	validation_1-auc:0.928298
# [136]	validation_0-auc:0.998168	validation_1-auc:0.928482
# [137]	validation_0-auc:0.998259	validation_1-auc:0.928493
# [138]	validation_0-auc:0.998333	validation_1-auc:0.928539
# [139]	validation_0-auc:0.998406	validation_1-auc:0.928959
# [140]	validation_0-auc:0.998495	validation_1-auc:0.928946
# [141]	validation_0-auc:0.998558	validation_1-auc:0.929072
# [142]	validation_0-auc:0.998616	validation_1-auc:0.929399
# [143]	validation_0-auc:0.998684	validation_1-auc:0.929433
# [144]	validation_0-auc:0.998735	validation_1-auc:0.929486
# [145]	validation_0-auc:0.998786	validation_1-auc:0.929582
# [146]	validation_0-auc:0.998845	validation_1-auc:0.929499
# [147]	validation_0-auc:0.9989	validation_1-auc:0.929567
# [148]	validation_0-auc:0.998951	validation_1-auc:0.929728
# [149]	validation_0-auc:0.999008	validation_1-auc:0.930164
# [150]	validation_0-auc:0.999059	validation_1-auc:0.930467
# [151]	validation_0-auc:0.999097	validation_1-auc:0.930451
# [152]	validation_0-auc:0.999141	validation_1-auc:0.930547
# [153]	validation_0-auc:0.99918	validation_1-auc:0.930765
# [154]	validation_0-auc:0.999224	validation_1-auc:0.930804
# [155]	validation_0-auc:0.99926	validation_1-auc:0.930967
# [156]	validation_0-auc:0.999288	validation_1-auc:0.931191
# [157]	validation_0-auc:0.999314	validation_1-auc:0.931123
# [158]	validation_0-auc:0.999341	validation_1-auc:0.931306
# [159]	validation_0-auc:0.999368	validation_1-auc:0.931465
# [160]	validation_0-auc:0.999405	validation_1-auc:0.931688
# [161]	validation_0-auc:0.999433	validation_1-auc:0.931767
# [162]	validation_0-auc:0.999455	validation_1-auc:0.931827
# [163]	validation_0-auc:0.999485	validation_1-auc:0.932037
# [164]	validation_0-auc:0.999505	validation_1-auc:0.932174
# [165]	validation_0-auc:0.999524	validation_1-auc:0.932299
# [166]	validation_0-auc:0.999537	validation_1-auc:0.932499
# [167]	validation_0-auc:0.999558	validation_1-auc:0.932493
# [168]	validation_0-auc:0.999578	validation_1-auc:0.932562
# [169]	validation_0-auc:0.999601	validation_1-auc:0.932657
# [170]	validation_0-auc:0.99962	validation_1-auc:0.932641
# [171]	validation_0-auc:0.999635	validation_1-auc:0.932769
# [172]	validation_0-auc:0.999646	validation_1-auc:0.932897
# [173]	validation_0-auc:0.999659	validation_1-auc:0.933156
# [174]	validation_0-auc:0.999672	validation_1-auc:0.933194
# [175]	validation_0-auc:0.999684	validation_1-auc:0.933384
# [176]	validation_0-auc:0.999697	validation_1-auc:0.933664
# [177]	validation_0-auc:0.999709	validation_1-auc:0.93383
# [178]	validation_0-auc:0.999722	validation_1-auc:0.933999
# [179]	validation_0-auc:0.999736	validation_1-auc:0.934157
# [180]	validation_0-auc:0.99975	validation_1-auc:0.934402
# [181]	validation_0-auc:0.999763	validation_1-auc:0.93451
# [182]	validation_0-auc:0.999778	validation_1-auc:0.934479
# [183]	validation_0-auc:0.999792	validation_1-auc:0.934495
# [184]	validation_0-auc:0.999803	validation_1-auc:0.934465
# [185]	validation_0-auc:0.999813	validation_1-auc:0.93456
# [186]	validation_0-auc:0.999818	validation_1-auc:0.93465
# [187]	validation_0-auc:0.999825	validation_1-auc:0.934687
# [188]	validation_0-auc:0.999831	validation_1-auc:0.934759
# [189]	validation_0-auc:0.999837	validation_1-auc:0.934915
# [190]	validation_0-auc:0.999846	validation_1-auc:0.934972
# [191]	validation_0-auc:0.999852	validation_1-auc:0.935038
# [192]	validation_0-auc:0.999857	validation_1-auc:0.935111
# [193]	validation_0-auc:0.999861	validation_1-auc:0.935168
# [194]	validation_0-auc:0.999868	validation_1-auc:0.935281
# [195]	validation_0-auc:0.999871	validation_1-auc:0.935303
# [196]	validation_0-auc:0.999876	validation_1-auc:0.935443
# [197]	validation_0-auc:0.999879	validation_1-auc:0.93563
# [198]	validation_0-auc:0.999882	validation_1-auc:0.935755
# [199]	validation_0-auc:0.999888	validation_1-auc:0.935781
# [200]	validation_0-auc:0.999891	validation_1-auc:0.935881
# [201]	validation_0-auc:0.999895	validation_1-auc:0.93588
# [202]	validation_0-auc:0.9999	validation_1-auc:0.935978
# [203]	validation_0-auc:0.999904	validation_1-auc:0.936038
# [204]	validation_0-auc:0.999908	validation_1-auc:0.936087
# [205]	validation_0-auc:0.999911	validation_1-auc:0.936141
# [206]	validation_0-auc:0.999915	validation_1-auc:0.936287
# [207]	validation_0-auc:0.999919	validation_1-auc:0.936333
# [208]	validation_0-auc:0.999923	validation_1-auc:0.936327
# [209]	validation_0-auc:0.999925	validation_1-auc:0.936484
# [210]	validation_0-auc:0.999929	validation_1-auc:0.936548
# [211]	validation_0-auc:0.99993	validation_1-auc:0.93655
# [212]	validation_0-auc:0.999933	validation_1-auc:0.936643
# [213]	validation_0-auc:0.999935	validation_1-auc:0.936671
# [214]	validation_0-auc:0.999938	validation_1-auc:0.936696
# [215]	validation_0-auc:0.999941	validation_1-auc:0.936715
# [216]	validation_0-auc:0.999943	validation_1-auc:0.936797
# [217]	validation_0-auc:0.999946	validation_1-auc:0.936866
# [218]	validation_0-auc:0.999946	validation_1-auc:0.936844
# [219]	validation_0-auc:0.999948	validation_1-auc:0.937014
# [220]	validation_0-auc:0.999951	validation_1-auc:0.937115
# [221]	validation_0-auc:0.999953	validation_1-auc:0.937142
# [222]	validation_0-auc:0.999954	validation_1-auc:0.937157
# [223]	validation_0-auc:0.999957	validation_1-auc:0.937117
# [224]	validation_0-auc:0.999959	validation_1-auc:0.937083
# [225]	validation_0-auc:0.99996	validation_1-auc:0.937158
# [226]	validation_0-auc:0.999962	validation_1-auc:0.937316
# [227]	validation_0-auc:0.999964	validation_1-auc:0.937267
# [228]	validation_0-auc:0.999965	validation_1-auc:0.937274
# [229]	validation_0-auc:0.999966	validation_1-auc:0.937194
# [230]	validation_0-auc:0.999967	validation_1-auc:0.937353
# [231]	validation_0-auc:0.999968	validation_1-auc:0.937459
# [232]	validation_0-auc:0.99997	validation_1-auc:0.937488
# [233]	validation_0-auc:0.999972	validation_1-auc:0.937517
# [234]	validation_0-auc:0.999973	validation_1-auc:0.937565
# [235]	validation_0-auc:0.999974	validation_1-auc:0.937609
# [236]	validation_0-auc:0.999975	validation_1-auc:0.937612
# [237]	validation_0-auc:0.999976	validation_1-auc:0.937704
# [238]	validation_0-auc:0.999977	validation_1-auc:0.937646
# [239]	validation_0-auc:0.999977	validation_1-auc:0.937679
# [240]	validation_0-auc:0.999978	validation_1-auc:0.937718
# [241]	validation_0-auc:0.999979	validation_1-auc:0.937738
# [242]	validation_0-auc:0.99998	validation_1-auc:0.937817
# [243]	validation_0-auc:0.999981	validation_1-auc:0.937849
# [244]	validation_0-auc:0.999981	validation_1-auc:0.937807
# [245]	validation_0-auc:0.999982	validation_1-auc:0.937899
# [246]	validation_0-auc:0.999983	validation_1-auc:0.93795
# [247]	validation_0-auc:0.999984	validation_1-auc:0.937981
# [248]	validation_0-auc:0.999984	validation_1-auc:0.938065
# [249]	validation_0-auc:0.999985	validation_1-auc:0.938092
# [250]	validation_0-auc:0.999985	validation_1-auc:0.938085
# [251]	validation_0-auc:0.999986	validation_1-auc:0.938084
# [252]	validation_0-auc:0.999986	validation_1-auc:0.938051
# [253]	validation_0-auc:0.999987	validation_1-auc:0.938125
# [254]	validation_0-auc:0.999988	validation_1-auc:0.938127
# [255]	validation_0-auc:0.999988	validation_1-auc:0.938095
# [256]	validation_0-auc:0.999989	validation_1-auc:0.938125
# [257]	validation_0-auc:0.999989	validation_1-auc:0.938209
# [258]	validation_0-auc:0.99999	validation_1-auc:0.938287
# [259]	validation_0-auc:0.99999	validation_1-auc:0.938367
# [260]	validation_0-auc:0.99999	validation_1-auc:0.938395
# [261]	validation_0-auc:0.999991	validation_1-auc:0.938414
# [262]	validation_0-auc:0.999991	validation_1-auc:0.938397
# [263]	validation_0-auc:0.999991	validation_1-auc:0.938465
# [264]	validation_0-auc:0.999992	validation_1-auc:0.938527
# [265]	validation_0-auc:0.999992	validation_1-auc:0.938506
# [266]	validation_0-auc:0.999992	validation_1-auc:0.93853
# [267]	validation_0-auc:0.999992	validation_1-auc:0.938568
# [268]	validation_0-auc:0.999992	validation_1-auc:0.938586
# [269]	validation_0-auc:0.999993	validation_1-auc:0.938568
# [270]	validation_0-auc:0.999993	validation_1-auc:0.938605
# [271]	validation_0-auc:0.999994	validation_1-auc:0.938669
# [272]	validation_0-auc:0.999994	validation_1-auc:0.938718
# [273]	validation_0-auc:0.999994	validation_1-auc:0.938719
# [274]	validation_0-auc:0.999994	validation_1-auc:0.938744
# [275]	validation_0-auc:0.999994	validation_1-auc:0.938793
# [276]	validation_0-auc:0.999995	validation_1-auc:0.938812
# [277]	validation_0-auc:0.999995	validation_1-auc:0.938729
# [278]	validation_0-auc:0.999995	validation_1-auc:0.938725
# [279]	validation_0-auc:0.999995	validation_1-auc:0.938727
# [280]	validation_0-auc:0.999995	validation_1-auc:0.938728
# [281]	validation_0-auc:0.999996	validation_1-auc:0.938759
# [282]	validation_0-auc:0.999996	validation_1-auc:0.938701
# [283]	validation_0-auc:0.999996	validation_1-auc:0.938633
# [284]	validation_0-auc:0.999996	validation_1-auc:0.938637
# [285]	validation_0-auc:0.999996	validation_1-auc:0.938676
# [286]	validation_0-auc:0.999996	validation_1-auc:0.938656
# Stopping. Best iteration:
# [276]	validation_0-auc:0.999995	validation_1-auc:0.938812
#
# 15631.064803123474
# ROC accuracy: 0.9388116845370211
# [0.00058374 0.00069225 0.00118059 ... 0.00189566 0.00375809 0.00256558]
# /Users/ruiqianyang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Fold: 2
# 472432 118108
# [0]	validation_0-auc:0.87777	validation_1-auc:0.836748
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.887526	validation_1-auc:0.857287
# [2]	validation_0-auc:0.891486	validation_1-auc:0.861067
# [3]	validation_0-auc:0.897004	validation_1-auc:0.866336
# [4]	validation_0-auc:0.901919	validation_1-auc:0.86977
# [5]	validation_0-auc:0.904285	validation_1-auc:0.871352
# [6]	validation_0-auc:0.908292	validation_1-auc:0.873514
# [7]	validation_0-auc:0.910068	validation_1-auc:0.874353
# [8]	validation_0-auc:0.911099	validation_1-auc:0.875731
# [9]	validation_0-auc:0.912812	validation_1-auc:0.877732
# [10]	validation_0-auc:0.914782	validation_1-auc:0.878937
# [11]	validation_0-auc:0.91611	validation_1-auc:0.880095
# [12]	validation_0-auc:0.917369	validation_1-auc:0.880409
# [13]	validation_0-auc:0.919932	validation_1-auc:0.88187
# [14]	validation_0-auc:0.921875	validation_1-auc:0.882252
# [15]	validation_0-auc:0.923224	validation_1-auc:0.883387
# [16]	validation_0-auc:0.924162	validation_1-auc:0.883696
# [17]	validation_0-auc:0.92508	validation_1-auc:0.883647
# [18]	validation_0-auc:0.926558	validation_1-auc:0.884752
# [19]	validation_0-auc:0.927549	validation_1-auc:0.885054
# [20]	validation_0-auc:0.928388	validation_1-auc:0.885596
# [21]	validation_0-auc:0.930069	validation_1-auc:0.886073
# [22]	validation_0-auc:0.930456	validation_1-auc:0.886023
# [23]	validation_0-auc:0.931206	validation_1-auc:0.886125
# [24]	validation_0-auc:0.934429	validation_1-auc:0.887974
# [25]	validation_0-auc:0.934868	validation_1-auc:0.887975
# [26]	validation_0-auc:0.937165	validation_1-auc:0.88974
# [27]	validation_0-auc:0.937769	validation_1-auc:0.890234
# [28]	validation_0-auc:0.938645	validation_1-auc:0.890542
# [29]	validation_0-auc:0.940711	validation_1-auc:0.8917
# [30]	validation_0-auc:0.942127	validation_1-auc:0.892547
# [31]	validation_0-auc:0.943693	validation_1-auc:0.892873
# [32]	validation_0-auc:0.945283	validation_1-auc:0.894174
# [33]	validation_0-auc:0.946301	validation_1-auc:0.894508
# [34]	validation_0-auc:0.947332	validation_1-auc:0.895409
# [35]	validation_0-auc:0.949717	validation_1-auc:0.896461
# [36]	validation_0-auc:0.950374	validation_1-auc:0.896979
# [37]	validation_0-auc:0.950802	validation_1-auc:0.897275
# [38]	validation_0-auc:0.951203	validation_1-auc:0.897535
# [39]	validation_0-auc:0.952674	validation_1-auc:0.899135
# [40]	validation_0-auc:0.953557	validation_1-auc:0.89989
# [41]	validation_0-auc:0.954819	validation_1-auc:0.900124
# [42]	validation_0-auc:0.95826	validation_1-auc:0.901981
# [43]	validation_0-auc:0.95922	validation_1-auc:0.903035
# [44]	validation_0-auc:0.959849	validation_1-auc:0.903311
# [45]	validation_0-auc:0.960461	validation_1-auc:0.903503
# [46]	validation_0-auc:0.961424	validation_1-auc:0.903858
# [47]	validation_0-auc:0.962823	validation_1-auc:0.904315
# [48]	validation_0-auc:0.963349	validation_1-auc:0.904452
# [49]	validation_0-auc:0.964338	validation_1-auc:0.905509
# [50]	validation_0-auc:0.965056	validation_1-auc:0.906164
# [51]	validation_0-auc:0.965434	validation_1-auc:0.906532
# [52]	validation_0-auc:0.966094	validation_1-auc:0.907064
# [53]	validation_0-auc:0.966516	validation_1-auc:0.907341
# [54]	validation_0-auc:0.967493	validation_1-auc:0.907898
# [55]	validation_0-auc:0.968242	validation_1-auc:0.908714

# %%
#XGB GROUP kfold##################################
import xgboost as xgb
from sklearn.model_selection import KFold,GroupKFold
import time
start=time.time()
       
def make_predictions(tr_df, tt_df, features_columns, target, 
                      NFOLDS=7):
    
    folds = GroupKFold(n_splits=NFOLDS)  #GroupKFold by DT_M

    X,y = tr_df[features_columns], tr_df[target]    
    P,P_y = tt_df[features_columns], tt_df[target]  
    split_groups = tr_df['DT_M']      #GroupKFold by XX

    tt_df = tt_df[['TransactionID',target]] 
    predictions = np.zeros(len(tt_df))
    
 
    for fold_, (trn_idx, val_idx) in enumerate(folds.split(X, y, groups=split_groups)): #GroupKFold by XX
        print('Fold:',fold_)
        tr_x, tr_y = X.iloc[trn_idx,:], y[trn_idx]
        vl_x, vl_y = X.iloc[val_idx,:], y[val_idx]
            
        print(len(tr_x),len(vl_x))
#         tr_data = xgb.DMatrix(tr_x, label=tr_y)
#         vl_data = xgb.DMatrix(vl_x, label=vl_y)
#         P_D = xgb.DMatrix(P)
        
        print('train month is '+str(tr_x['month'].unique()))
        print('test month is '+str(vl_x['month'].unique()))
#        tr_data = lgb.Dataset(tr_x, label=tr_y)

#         if LOCAL_TEST:
#             vl_data = lgb.Dataset(P, label=P_y) 
#         else:
#             vl_data = lgb.Dataset(vl_x, label=vl_y)  

        clf = xgb.XGBClassifier(
             n_jobs=4,
            n_estimators=2000,
            max_depth=20,
            learning_rate=0.035,
            subsample=0.7,
            colsample_bytree=0.7463058454739352,
            #tree_method='gpu_hist',  # THE MAGICAL PARAMETER
            reg_alpha=0.39871702770778467,
            reg_lamdba=0.24309304355829786,
            random_state=2019
#                gamma=0.6665437467229817,
#                min_child_weight=,
#                max_delta_step=,
#           min_child_samples= 170
        )
    
        clf.fit(tr_x, tr_y,eval_set = [(tr_x, tr_y),(vl_x, vl_y)], eval_metric="auc",
                early_stopping_rounds = 50)
        print(time.time()-start)
        print('ROC accuracy: {}'.format(roc_auc_score(vl_y, clf.predict_proba(vl_x)[:, 1])))
        #pp_p+= clf.predict_proba(P)[:,1] 
     
        pp_p = clf.predict_proba(P)[:,1]
        
        print(pp_p)
        tt_df['fold '+str(fold_)]=pp_p
        predictions += pp_p/NFOLDS     #consider weighting predictions??
       # print('weight is '+str(w[fold_]))
       # predictions += pp_p*w[fold_]
        
        if LOCAL_TEST:
            feature_imp = pd.DataFrame(sorted(zip(estimator.feature_importance(),X.columns)), 
                                       columns=['Value','Feature'])
            print(feature_imp)
        
        del tr_x, tr_y, vl_x, vl_y
        gc.collect()
    
    tt_df['prediction'] = predictions
    
    return tt_df   

########################### Model Train
LOCAL_TEST = False
TARGET = 'isFraud'

#assign train_df and test_df:
train_df=X.iloc[:]
train_df['isFraud']=y['isFraud']
test_df=test_x.iloc[:]
test_df['isFraud']=0
train_df=train_df.reset_index(drop=False)
test_df=test_df.reset_index(drop=False)
    
#make sure 'DT_M' and'TransactionID' are not in feature list
features_columns=list(set(X)-{'DT_M','TransactionID'})     
print(len(features_columns))
print(len(X.columns))

test_predictions = make_predictions(train_df, test_df, features_columns, TARGET,NFOLDS=7)
####End GROUPKFOLD

# %%
test_predictions.head()

# %%
#important to reset index
test_x=test_x.reset_index(drop=False)

test_predictions.to_csv("XGB_Kfold_predictions_every_fold.csv",index=False)

#for kfold/groupkfold/stratifiedkfold
test_x['isFraud']=test_predictions['prediction']

# %%
output=test_x[['TransactionID','isFraud']]
#output['isFraud']=test_x['isFraud']

# %%
#test.shape
output.to_csv("output_submission_XGB_Kfold.csv",index=False)

#output1=output.copy()
#output1['isFraud']=test_predictions['fold 9']
#output1.to_csv("output_submission_v6_Kfold10_r227_9.csv",index=False)
